# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract Excel data into DataFrames

# %%
file = "Resources/Dec19.xls"
df = pd.read_excel(file, sheet_name='Island',header=67, skipfooter=57)
df.head(150)
# Out:
#              MONTH-TO-DATE         ISLAND      Jan      Feb      Mar      Apr  \
# 0   EXPENDITURES ($mil.) *  TOTAL ($mil.)  1631.89  1393.64  1506.36  1327.04
# 1                      NaN   Total by air  1628.45  1388.71  1502.73  1318.53
# 2                      NaN          O‘ahu  711.664  617.275  690.716  627.482
# 3                      NaN           Maui  474.194  413.872  440.272  391.867
# 4                      NaN       Moloka'i  2.87478  3.28657  3.65689  3.28485
# ..                     ...            ...      ...      ...      ...      ...
# 61  EXPENDITURES ($mil.) *  TOTAL ($mil.)  1631.89  3025.53  4531.89  5858.93
# 62                     NaN   Total by air  1628.45  3017.16  4519.88  5838.41
# 63                     NaN          O‘ahu  711.664  1328.94  2019.65  2647.14
# 64                     NaN           Maui  474.194  888.067  1328.34  1720.21
# 65                     NaN       Moloka'i  2.87478  6.16135  9.81824  13.1031
#
# ...

# %% [markdown]
# ### Transform Visitor DataFrame

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/HawaiiTourism_DB"
engine = create_engine(f'postgresql://{connection_string}')

# %% [markdown]
# ### Load DataFrames into database
